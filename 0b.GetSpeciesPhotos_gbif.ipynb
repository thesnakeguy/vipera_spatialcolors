# %% [markdown]
# # import packages

# %%
import os
import pandas as pd
import random
import time
import shutil
import requests
import matplotlib.pyplot as plt
from pygbif import occurrences as occ
from pygbif import species 
from PIL import Image
import numpy as np
from typing_extensions import Counter

# %% [markdown]
# # Initialize function to scrape images from Inaturalist

# %%
# Scrape Images and Metadata

# Here we make a function to save photos of a target species locally and save necessary metada: latitude, longitude, observation ID, photo IDs, Photo urls. Metadata is saved as a dictionary and photos are saved in a directory specified by the user.
# Metadata example:
# observation_id   latitude  longitude  observation_date  photo_ids  \
# 0       259323505  57.736160  10.629406 date  [465488543]
# 1       259193935  48.037273  11.509971 date  [465220887]
# 2       258982331  49.385485  19.790977 date  [464790765]
# 3       258835093  46.517517   9.908752 date  [464493974]
# 4       258811645  52.674268   6.516881 date  [464445739]
#
#                                               photos
# 0  [https://inaturalist-open-data.s3.amazonaws.co...
# 1  [https://inaturalist-open-data.s3.amazonaws.co...
# 2  [https://static.inaturalist.org/photos/4647907...
# 3  [https://static.inaturalist.org/photos/4644939...
# 4  [https://static.inaturalist.org/photos/4644457...

# Parameters
# --- Parameters ---
# Note: GBIF requires the Taxon Key (a numeric ID), not the species name string,
output_dir = "C:/Users/pdeschepper/OneDrive - Institute of Natural Sciences/Desktop/PERSONAL/DeepLearning/vipera_spatialcolors/Vipera_latastei_gbif_sourceimages"
record_limiter = 100000
# GBIF occ.search() default limit is 200, max is 100,000 for a single search, 
# but we will manually loop for pagination.
PAGE_LIMIT = 200


def get_gbif_taxon_key(species_name):
    """Looks up the GBIF Taxon Key (usageKey) for a given scientific name."""
    result = species.name_backbone(scientificName=species_name, taxonRank="SPECIES")
    return result["usage"]["key"]

def scrape_gbif_images(species_name):
    """Scrape images and metadata for a target species from GBIF."""
    
    # 1. Get the Taxon Key
    taxon_key = get_gbif_taxon_key(species_name)
    if not taxon_key:
        print(f"❌ Could not find a GBIF Taxon Key for '{species_name}'. Aborting.")
        return []

    print(f"Found GBIF Taxon Key: {taxon_key}")
    
    # 2. Setup File System
    if os.path.exists(output_dir) and os.listdir(output_dir):
        # Clear existing image/csv files
        for file in os.listdir(output_dir):
            if file.endswith((".jpg", ".csv")):
                 os.remove(os.path.join(output_dir, file))
    else:
        os.makedirs(output_dir, exist_ok=True)


    # 3. Fetch Observations (Paginated Loop)
    observations = []
    offset = 0
    total_records_retrieved = 0

    while total_records_retrieved < record_limiter:
        print(f"Fetching records starting at offset {offset}...")
        try:
            # GBIF API search parameters
            response = occ.search(
                taxonKey=taxon_key,
                basisOfRecord='HUMAN_OBSERVATION',  # Human observations only
                hasCoordinate=True,          # Must have coordinates
                hasGeospatialIssue=False,    # Should have no spatial issues
                mediaType='StillImage',      # Must have image/multimedia data
                continent='europe',                  # Restrict results to Europe
                coordinateUncertaintyInMeters='0,30000', # Uncertainty between 0 and 500m
                limit=min(PAGE_LIMIT, record_limiter - total_records_retrieved),
                offset=offset
            )
        
        except Exception as e:
            print(f"An error occurred during GBIF API call: {e}")
            break

        current_results = response.get('results', [])

        if not current_results:
            print("Reached the end of available records or results are empty.")
            break

        observations.extend(current_results)
        
        total_records_retrieved = len(observations)
        print(f"  -> Collected {total_records_retrieved} of {record_limiter} so far.")

        # Check for exit conditions
        if response.get('endOfRecords') or total_records_retrieved >= record_limiter:
            break

        # Increment offset for next iteration
        offset += PAGE_LIMIT
        
        # Add a delay between API calls to be polite
        time.sleep(1)


    # 4. Process Observations, Download Images, and Store Metadata
    metadata = []
    s = requests.Session() 
    
    for obs in observations[:record_limiter]: # Limit to max requested
        
        # Core Metadata fields
        occurrence_id = obs.get('gbifID', None)
        latitude = obs.get('decimalLatitude', None)
        longitude = obs.get('decimalLongitude', None)
        # 🌟 GBIF date field is typically 'eventDate'
        observation_date = obs.get('eventDate', None) 
        
        # Multimedia is a list of dictionaries
        multimedia = obs.get('media', []) 
        
        photo_urls = []
        photo_ids = []

        # Download and save photos for this occurrence
        for media_item in multimedia:
            # GBIF uses 'identifier' for the original photo URL
            img_url = media_item.get('identifier', None)
            
            # Use a unique identifier for the filename. We use the original URL's hash 
            # or the media key if available, but for simplicity, let's use a combination
            # of the GBIF ID and an index, as a stable 'photo ID' is not guaranteed.
            # Using a simple index here is a compromise.
            photo_index = f"{occurrence_id}_{multimedia.index(media_item) + 1}"
            img_path = os.path.join(output_dir, f"{photo_index}.jpg")
            
            if not img_url:
                continue

            try:
                # Use the session for downloading
                img_response = s.get(img_url, timeout=10)
                img_response.raise_for_status()
                
                with open(img_path, 'wb') as f:
                    f.write(img_response.content)
                
                photo_urls.append(img_url)
                photo_ids.append(photo_index) # Store the filename ID

            except Exception as e:
                print(f"Error downloading media for {occurrence_id} from {img_url}: {e}")
                continue

        # Append metadata for the observation (only if images were successfully downloaded)
        if photo_urls:
             metadata.append({
                "gbif_id": occurrence_id,
                "latitude": latitude,
                "longitude": longitude,
                "observation_date": observation_date,
                "photo_ids": photo_ids,
                "photos": photo_urls
            })
            
    # 5. Save Metadata to CSV
    if metadata:
        df = pd.DataFrame(metadata)
        csv_path = os.path.join(output_dir, f"{species_name.replace(' ', '_')}_gbif_metadata.csv")
        df.to_csv(csv_path, index=False)
        print(f"\n✅ Successfully saved {len(metadata)} records and images to {output_dir}")
        print(f"✅ Metadata saved to: {csv_path}")
    else:
        print("⚠️ No records with images were successfully processed.")

    return metadata

# %% [markdown]
# # Use scraping function

# %%
# Usage
scrape_gbif_images("Vipera latastei")
# Out:
# Found GBIF Taxon Key: 5960896
# Fetching records starting at offset 0...
#   -> Collected 200 of 100000 so far.
# Fetching records starting at offset 200...
#   -> Collected 400 of 100000 so far.
# Fetching records starting at offset 400...
#   -> Collected 600 of 100000 so far.
# Fetching records starting at offset 600...
#   -> Collected 651 of 100000 so far.
#
# ✅ Successfully saved 651 records and images to C:/Users/pdeschepper/OneDrive - Institute of Natural Sciences/Desktop/PERSONAL/DeepLearning/vipera_spatialcolors/Vipera_latastei_gbif_sourceimages
# ✅ Metadata saved to: C:/Users/pdeschepper/OneDrive - Institute of Natural Sciences/Desktop/PERSONAL/DeepLearning/vipera_spatialcolors/Vipera_latastei_gbif_sourceimages\Vipera_latastei_gbif_metadata.csv
# [{'gbif_id': '6151094097',
#   'latitude': 37.0,
#   'longitude': -6.6,
#   'observation_date': '2026-01-31',
#   'photo_ids': ['6151094097_1'],
#   'photos': ['https://observation.org/photos/143819180.jpg']},
#  {'gbif_id': '6163252981',
#   'latitude': 38.112528,
#   'longitude': -7.064358,
#   'observation_date': '2026-02-21T14:48:09Z',
#   'photo_ids': ['6163252981_1'],
#   'photos': ['https://inaturalist-open-data.s3.amazonaws.com/photos
1'],
#   'photos': ['https://inaturalist-open-data.s3.amazonaws.com/photos/623512805/original.jpg']},
#  {'gbif_id': '5107996021',
#   'latitude': 42.6,
#   'longitude': -4.05,
#   'observation_date': '2025-04-07',
#   'photo_ids': ['5107996021_1', '5107996021_2'],
#   'photos': ['https://observation.org/photos/113352631.jpg',
#    'https://observation.org/photos/113397901.jpg']},
#  {'gbif_id': '5108832248',
#   'latitude': 36.5,
#   'longitude': -5.65,
#   'observation_date': '2025-04-10',
#   'photo_ids': ['5108832248_1', '5108832248_2'],
#   'photos': ['https://observation.org/photos/113560116.jpg',
#    'https://observation.org/photos/113560118.jpg']},
#  {'gbif_id': '5108902180',
#   'latitude': 36.5,
#   'longitude': -5.65,
#   'observation_date': '2025-04-10',
#   'photo_ids': ['5108902180_1',
#    '5108902180_2',
#    '5108902180_3',
#    '5108902180_4',
#    '5108902180_5'],
#   'photos': ['https://observation.org/photos/113564524.jpg',
#    'https://observation.org/photos/113564525.jpg',
#    'https://observation.org/photos/113564526.jpg',
#    'https://observation.org/photos/113564527.jpg',
#    'https://observation.org/photos/113564528.jpg']},
#  {'gbif_id': '5132165761',
#   'latitude': 41.8,
#   'longitude': -2.1,
#   'observation_date': '2025-04-18',
#   'photo_ids': ['5132165761_1'],
#   'photos': ['https://observation.org/photos/114264614.jpg']},
#  {'gbif_id': '5133564233',
#   'latitude': 41.86083,
#   'longitude': -8.146758,
#   'observation_date': '2025-04-13T15:35:42',
#   'photo_ids': ['5133564233_1', '5133564233_2'],
#   'photos': ['https://inaturalist-open-data.s3.amazonaws.com/photos/486023073/original.jpg',
#    'https://inaturalist-open-data.s3.amazonaws.com/photos/486023990/original.jpg']},
#  {'gbif_id': '5134555424',
#   'latitude': 39.439259,
#   'longitude': -8.980843,
#   'observation_date': '2025-04-05T15:16:54',
#   'photo_ids': ['5134555424_1', '5134555424_2', '5134555424_3'],
#   'photos': ['https://inaturalist-open-data.s3.amazonaws.com/photos/483219936/original.jpg',
#    'https://inaturalist-open-data.s3.amazonaws.com/photos/483219881/original.jpg',
#    'https://inaturalist-open-data.s3.amazonaws.com/photos/483219975/original.jpg']},
#  {'gbif_id': '5134680163',
#   'latitude': 41.451079,
#   'longitude': -7.613274,
#   'observation_date': '2025-04-09T14:26',
#   'photo_ids': ['5134680163_1'],
#   'photos': ['https://inaturalist-open-data.s3.amazonaws.com/photos/484575167/original.jpeg']},
#  {'gbif_id': '5138850726',
#   'latitude': 38.15,
#   'longitude': -4.0,
#   'observation_date': '2025-04-17',
#   'photo_ids': ['5138850726_1'],
#   'photos': ['https://observation.org/photos/117584504.jpg']},
#  {'gbif_id': '5138852840',
#   'latitude': 38.15,
#   'longitude': -3.95,
#   'observation_date': '2025-04-22',
#   'photo_ids': ['5138852840_1'],
#   'photos': ['https://observation.org/photos/114716832.jpg']},
#  {'gbif_id': '5140116489',
#   'latitude': 41.034655,
#   'longitude': -3.564091,
#   'observation_date': '2025-04-23T10:29:03',
#   'photo_ids': ['5140116489_1'],
#   'photos': ['https://inaturalist-open-data.s3.amazonaws.com/photos/490301102/original.jpeg']},
#  {'gbif_id': '5153122456',
#   'latitude': 42.700985,
#   'longitude': -3.650316,
#   'observation_date': '2025-04-30T17:27:11',
#   'photo_ids': ['5153122456_1',
#    '5153122456_2',
#    '5153122456_3',
#    '5153122456_4'],
#   'photos': ['https://inaturalist-open-data.s3.amazonaws.com/photos/498144727/original.jpg',
#    'https://inaturalist-open-data.s3.amazonaws.com/photos/498144805/original.jpg',
#    'https://inaturalist-open-data.s3.amazonaws.com/photos/498145590/original.jpg',
#    'https://inaturalist-open-data.s3.amazonaws.com/photos/498145689/original.jpg']},
#  {'gbif_id': '5154616235',
#   'latitude': 40.588272,
#   'longitude': -4.244806,
#   'observation_date': '2025-04-26T11:59:10',
#   'photo_ids': ['5154616235_1', '5154616235_2'],
#   'photos': ['https://inaturalist-open-data.s3.amazonaws.com/photos/499442019/original.jpeg',
#    'https://inaturalist-open-data.s3.amazonaws.com/photos
1'],
#   'photos': ['https://inaturalist-open-data.s3.amazonaws.com/photos/541295010/original.jpg']},
#  {'gbif_id': '5238321782',
#   'latitude': 40.616664,
#   'longitude': -4.394941,
#   'observation_date': '2025-07-23T15:37:29',
#   'photo_ids': ['5238321782_1'],
#   'photos': ['https://inaturalist-open-data.s3.amazonaws.com/photos/541303484/original.jpg']},
#  {'gbif_id': '5281923114',
#   'latitude': 40.917529,
#   'longitude': -4.142586,
#   'observation_date': '2025-07-23T18:05',
#   'photo_ids': ['5281923114_1'],
#   'photos': ['https://inaturalist-open-data.s3.amazonaws.com/photos/545325952/original.jpg']},
#  {'gbif_id': '5282127511',
#   'latitude': 41.877084,
#   'longitude': -6.223022,
#   'observation_date': '2025-07-24T22:42',
#   'photo_ids': ['5282127511_1'],
#   'photos': ['https://inaturalist-open-data.s3.amazonaws.com/photos/544952432/original.jpg']},
#  {'gbif_id': '5282574916',
#   'latitude': 41.696894,
#   'longitude': -8.194168,
#   'observation_date': '2025-07-22T11:50:54',
#   'photo_ids': ['5282574916_1', '5282574916_2'],
#   'photos': ['https://inaturalist-open-data.s3.amazonaws.com/photos/545325937/original.jpg',
#    'https://inaturalist-open-data.s3.amazonaws.com/photos/545325982/original.jpg']},
#  {'gbif_id': '5292001597',
#   'latitude': 40.827861,
#   'longitude': -4.199502,
# ...
#  {'gbif_id': '4922021375',
#   'latitude': 41.620218,
#   'longitude': -2.389628,
#   'observation_date': '2014-04-14T13:57',
#   'photo_ids': ['4922021375_1',
#    '4922021375_2',
#    '4922021375_3',
#    '4922021375_4',
#    '4922021375_5',
#    '4922021375_6'],
#   'photos': ['https://inaturalist-open-data.s3.amazonaws.com/photos/415449877/original.jpg',
#    'https://inaturalist-open-data.s3.amazonaws.com/photos/415449879/original.jpg',
#    'https://inaturalist-open-data.s3.amazonaws.com/photos/415449904/original.jpg',
#    'https://inaturalist-open-data.s3.amazonaws.com/photos/415449915/original.jpg',
#    'https://inaturalist-open-data.s3.amazonaws.com/photos/415449909/original.jpg',
#    'https://inaturalist-open-data.s3.amazonaws.com/photos/415449946/original.jpg']},
#  {'gbif_id': '3985754255',
#   'latitude': 40.580586,
#   'longitude': -7.517757,
#   'observation_date': '2014-05-10T19:34',
#   'photo_ids': ['3985754255_1'],
#   'photos': ['https://inaturalist-open-data.s3.amazonaws.com/photos/243955029/original.jpg']},
#  {'gbif_id': '4921856906',
#   'latitude': 40.486654,
#   'longitude': -5.215332,
#   'observation_date': '2014-05-18T19:16',
#   'photo_ids': ['4921856906_1'],
#   'photos': ['https://inaturalist-open-data.s3.amazonaws.com/photos/415450274/original.jpg']},
#  {'gbif_id': '3726181438',
#   'latitude': 36.95,
#   'longitude': -6.45,
#   'observation_date': '2014-06-28',
#   'photo_ids': ['3726181438_1'],
#   'photos': ['https://observation.org/photos/28397540.jpg']},
#  {'gbif_id': '3726332413',
#   'latitude': 36.95,
#   'longitude': -6.45,
#   'observation_date': '2014-06-28',
#   'photo_ids': ['3726332413_1'],
#   'photos': ['https://observation.org/photos/28397541.jpg']},
#  {'gbif_id': '4921639469',
#   'latitude': 40.584821,
#   'longitude': -6.309566,
#   'observation_date': '2014-06-04T11:56',
#   'photo_ids': ['4921639469_1'],
#   'photos': ['https://inaturalist-open-data.s3.amazonaws.com/photos/415450424/original.jpg']},
#  {'gbif_id': '2573839305',
#   'latitude': 40.282289,
#   'longitude': -7.791626,
#   'observation_date': '2014-07-30T19:30',
#   'photo_ids': ['2573839305_1'],
#   'photos': ['https://inaturalist-open-data.s3.amazonaws.com/photos/61055809/original.jpeg']},
#  {'gbif_id': '3729861787',
#   'latitude': 42.7,
#   'longitude': -3.8,
#   'observation_date': '2014-07-04',
#   'photo_ids': ['3729861787_1'],
#   'photos': ['https://observation.org/photos/40038196.jpg']},
#  {'gbif_id': '1038340344',
#   'latitude': 41.450941,
#   'longitude': 1.984774,
#   'observation_date': '2014-10-25T11:16:32',
#   'photo_ids': ['1038340344_1'],
#   'photos': ['https://inaturalist-open-data.s3.amazonaws.com/photos/1302075/original.jpg']},
#  {'gbif_id': '3903396620',
#   'latitude': 41.556323,
#   'longitude': 1.874122,
#   'observation_date': '2014-10-11T10:35',
#   'photo_ids': ['3903396620_1'],
#   'photos': ['https://inaturalist-open-data.s3.amazonaws.com/photos/228609423/original.jpg']},
#  {'gbif_id': '4528104303',
#   'latitude': 40.113017,
#   'longitude': -0.813511,
#   'observation_date': '2014-10-23T13:09',
#   'photo_ids': ['4528104303_1', '4528104303_2'],
#   'photos': ['https://inaturalist-open-data.s3.amazonaws.com/photos
1'],
#   'photos': ['https://inaturalist-open-data.s3.amazonaws.com/photos/351639619/original.jpeg']},
#  {'gbif_id': '6150440929',
#   'latitude': 39.3,
#   'longitude': -7.3,
#   'observation_date': '2008-05-11',
#   'photo_ids': ['6150440929_1'],
#   'photos': ['https://observation.org/photos/143549192.jpg']},
#  {'gbif_id': '4410110867',
#   'latitude': 37.7,
#   'longitude': -3.5,
#   'observation_date': '2008-09-20',
#   'photo_ids': ['4410110867_1'],
#   'photos': ['https://observation.org/photos/73446585.jpg']},
#  {'gbif_id': '5230459452',
#   'latitude': 41.780496,
#   'longitude': -8.159965,
#   'observation_date': '2007-04-22T11:17:45',
#   'photo_ids': ['5230459452_1'],
#   'photos': ['https://inaturalist-open-data.s3.amazonaws.com/photos/322798109/original.jpeg']},
#  {'gbif_id': '5008739332',
#   'latitude': 37.01225,
#   'longitude': -6.559302,
#   'observation_date': '2007-10-09',
#   'photo_ids': ['5008739332_1', '5008739332_2', '5008739332_3'],
#   'photos': ['https://observation.org/photos/108709092.jpg',
#    'https://observation.org/photos/108709093.jpg',
#    'https://observation.org/photos/108709094.jpg']},
#  {'gbif_id': '4407431064',
#   'latitude': 36.120665,
#   'longitude': -5.212328,
#   'observation_date': '2006-08-11T17:44',
#   'photo_ids': ['4407431064_1', '4407431064_2'],
#   'photos': ['https://inaturalist-open-data.s3.amazonaws.com/photos/316238176/original.jpg',
#    'https://inaturalist-open-data.s3.amazonaws.com/photos/316238174/original.jpg']},
#  {'gbif_id': '4459935914',
#   'latitude': 36.185336,
#   'longitude': -5.364783,
#   'observation_date': '2006-08-11',
#   'photo_ids': ['4459935914_1', '4459935914_2'],
#   'photos': ['https://observation.org/photos/76549218.jpg',
#    'https://observation.org/photos/76549219.jpg']},
#  {'gbif_id': '4908545970',
#   'latitude': 38.742042,
#   'longitude': -0.531852,
#   'observation_date': '2005-03-30T11:28',
#   'photo_ids': ['4908545970_1'],
#   'photos': ['https://inaturalist-open-data.s3.amazonaws.com/photos/404215610/original.jpeg']},
#  {'gbif_id': '4525123738',
#   'latitude': 37.215361,
#   'longitude': -8.749896,
#   'observation_date': '2005-04-24T18:03',
#   'photo_ids': ['4525123738_1'],
#   'photos': ['https://inaturalist-open-data.s3.amazonaws.com/photos/351634725/original.jpeg']},
#  {'gbif_id': '4980684003',
#   'latitude': 40.092424,
#   'longitude': -8.291407,
#   'observation_date': '2004-01-01T17:32Z',
#   'photo_ids': ['4980684003_1'],
#   'photos': ['https://inaturalist-open-data.s3.amazonaws.com/photos/448886697/original.jpg']},
#  {'gbif_id': '2988582925',
#   'latitude': 41.705022,
#   'longitude': -2.653875,
#   'observation_date': '2003-05-02',
#   'photo_ids': ['2988582925_1', '2988582925_2'],
#   'photos': ['https://inaturalist-open-data.s3.amazonaws.com/photos/104257688/original.jpg',
#    'https://inaturalist-open-data.s3.amazonaws.com/photos/104257825/original.jpg']},
#  {'gbif_id': '6399610042',
#   'latitude': 41.731856,
#   'longitude': -2.704342,
#   'observation_date': '2003-05-10',
#   'photo_ids': ['6399610042_1',
#    '6399610042_2',
#    '6399610042_3',
#    '6399610042_4',
#    '6399610042_5'],
#   'photos': ['https://inaturalist-open-data.s3.amazonaws.com/photos/675887521/original.jpg',
#    'https://inaturalist-open-data.s3.amazonaws.com/photos/675887520/original.jpg',
#    'https://inaturalist-open-data.s3.amazonaws.com/photos/675887516/original.jpg',
#    'https://inaturalist-open-data.s3.amazonaws.com/photos/675887535/original.jpg',
#    'https://inaturalist-open-data.s3.amazonaws.com/photos/675887537/original.jpg']},
#  {'gbif_id': '4080512888',
#   'latitude': 36.246601,
#   'longitude': -5.324215,
#   'observation_date': '2002-11-29T23:45:16',
#   'photo_ids': ['4080512888_1'],
#   'photos': ['https://inaturalist-open-data.s3.amazonaws.com/photos/265528348/original.jpeg']},
#  {'gbif_id': '3333272669',
#   'latitude': 38.657481,
#   'longitude': -0.560241,
#   'observation_date': '1999-01-22T21:52Z',
#   'photo_ids': ['3333272669_1'],
#   'photos': ['https://inaturalist-open-data.s3.amazonaws.com/photos/145561964/original.jpeg']},
#  {'gbif_id': '3760256884',
#   'latitude': 41.069797,
#   'longitude': -3.231119,
#   'observation_date': '1984-06-23T12:00',
#   'photo_ids': ['3760256884_1', '3760256884_2', '3760256884_3'],
#   'photos': ['https://inaturalist-open-data.s3.amazonaws.com/photos/188038563/original.jpg',
#    'https://inaturalist-open-data.s3.amazonaws.com/photos/188038576/original.jpg',
#    'https://inaturalist-open-data.s3.amazonaws.com/photos/188038549/original.jpg']}]

# %% [markdown]
# # Open a photo and check size

# %%
# Get a list of all image files in the directory
image_files = []
for f in os.listdir(output_dir):
    if os.path.isfile(os.path.join(output_dir, f)):
        image_files.append(f)

# Select a random image file
random_image_file = random.choice(image_files)

# Construct the full path to the random image
random_image_path = os.path.join(output_dir, random_image_file)

# Open the random image
image = Image.open(random_image_path)

# Get dimensions
width, height = image.size
print(f"Width: {width}, Height: {height}")

# Display the image (optional)
display(image)

print(image_files)
# Out:
# Width: 1000, Height: 635
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1000x635>
# ['2836130398_1.jpg', '2836130398_2.jpg', '2836130398_3.jpg', '2836130398_4.jpg', '2841427591_1.jpg', '2841427591_2.jpg', '2841427591_3.jpg', '3722937237_1.jpg', '3722937237_10.jpg', '3722937237_11.jpg', '3722937237_2.jpg', '3722937237_3.jpg', '3722937237_4.jpg', '3722937237_5.jpg', '3722937237_6.jpg', '3722937237_7.jpg', '3722937237_8.jpg', '3722937237_9.jpg', '3731005832_1.jpg', '3731005832_2.jpg', '3731005832_3.jpg', '3825965104_1.jpg', '3827320067_1.jpg', '3827320067_2.jpg', '3995689061_1.jpg', '4058432899_1.jpg', '4058432899_2.jpg', '4058432899_3.jpg', '4459425151_1.jpg', '4459935914_1.jpg', '4459935914_2.jpg', '4882502441_1.jpg', '4985982889_1.jpg', '4985982889_2.jpg', '5008635200_1.jpg', '5008635200_2.jpg', '5008739332_1.jpg', '5008739332_2.jpg', '5008739332_3.jpg', '5015448463_1.jpg', '5015448463_2.jpg', '5164585801_1.jpg', '5164751199_1.jpg', '5901309242_1.jpg', '5901445011_1.jpg', '5901445011_2.jpg', '6183842415_1.jpg', '6186586171_1.jpg', '6186765394_1.jpg', '6228339469_1.jpg', '6343450499_1.jpg', 'Vipera_latastei_gbif_metadata.csv']

# %% [markdown]
# # Zip photos (.jpg)

# %%
import os
import zipfile

def zip_jpg_files(output_directory, zip_file_name="images.zip"):
    """
    This function zips all the .jpg files in a given directory.

    Args:
        output_directory: The directory where the .jpg files are located.
        zip_file_name: The name of the zip file to be created (default: "images.zip").

    Returns:
        None. It creates a zip file in the output directory.
    """

    # Create the full path for the zip file
    zip_file_path = os.path.join(output_directory, zip_file_name)

    # Open the zip file in write mode ('w')
    with zipfile.ZipFile(zip_file_path, 'w') as zip_file:
        # Go through all the files and folders in the output directory
        for current_folder, subfolders, files in os.walk(output_directory):
            # Check each file in the current folder
            for file_name in files:
                # If the file ends with '.jpg', add it to the zip file
                if file_name.endswith('.jpg'):
                    # Get the full path of the file
                    file_path = os.path.join(current_folder, file_name)

                    # Add the file to the zip file using its original name
                    zip_file.write(file_path, arcname=file_name)

    # Print a message to confirm the zip file creation
    print(f"All .jpg files in '{output_directory}' have been zipped to '{zip_file_name}'")


# Call the zip function
zip_jpg_files(output_dir)
# Out:
# All .jpg files in '/mnt/c/Users/pdeschepper/Desktop/Vipera_aspis_gbif_export/' have been zipped to 'images.zip'
